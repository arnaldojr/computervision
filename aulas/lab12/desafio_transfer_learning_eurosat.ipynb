# %% [markdown]
# # Desafio — Transfer Learning com EuroSAT
#
# **Nome:**
# **RM:**
# **Turma:**
#
# ---
#
# ## Objetivo
#
# Desenvolver e avaliar um classificador de imagens utilizando **Transfer Learning** no dataset EuroSAT.
#
# Você deverá implementar e comparar:
#
# 1. **Feature Extraction**
# 2. **Fine-Tuning**
#
# A especificação completa da atividade está disponível no site da disciplina.
#
# > Este notebook é apenas um ponto de partida. As decisões de implementação fazem parte do desafio.

# %% [markdown]
# ## Regras principais
#
# - Dataset obrigatório: **EuroSAT**
# - Divisão: **70% treino / 15% validação / 15% teste**
# - Seed: **42**
# - Não utilizar **MobileNetV3-Small**
# - Comparar Feature Extraction e Fine-Tuning pela **validação**
# - Utilizar o **teste somente uma vez**, depois da escolha do melhor experimento
# - Salvar o melhor checkpoint
# - Gerar matriz de confusão
# - Analisar pelo menos 8 erros de classificação

# %% [markdown]
# ## 0. Ambiente
#
# Configure o ambiente de execução e verifique se uma GPU está disponível.
#
# O código abaixo apenas identifica o dispositivo. Acrescente os imports necessários para sua solução.

# %%
import torch

SEED = 42
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f"Dispositivo: {device}")

# %% [markdown]
# # 1. Exploração do dataset
#
# Carregue o EuroSAT e investigue os dados antes de criar o modelo.
#
# Sua exploração deve mostrar:
#
# - classes;
# - quantidade total de imagens;
# - distribuição das classes;
# - pelo menos 10 imagens de exemplo.

# %%
# TODO: carregue e explore o dataset

# %% [markdown]
# ### Observações sobre o dataset
#
# Registre aqui o que você observou durante a exploração.
#
# - Quantas classes existem?
# - O dataset parece balanceado?
# - Quais classes parecem visualmente mais semelhantes?
#
# **Resposta:**

# %% [markdown]
# # 2. Preparação e divisão dos dados
#
# Crie os conjuntos de:
#
# - treino: 70%
# - validação: 15%
# - teste: 15%
#
# Use `seed = 42`.
#
# Prepare também as transformações de imagem compatíveis com os pesos pré-treinados da arquitetura que você escolher.

# %%
# TODO: defina as transformações e faça a divisão dos dados

# %% [markdown]
# ## DataLoaders
#
# Crie um `DataLoader` para cada conjunto.
#
# O conjunto de treino pode utilizar shuffle. Validação e teste devem permanecer determinísticos.

# %%
# TODO: crie trainloader, valloader e testloader

# %% [markdown]
# # 3. Escolha do backbone
#
# Escolha uma arquitetura pré-treinada diferente de **MobileNetV3-Small**.
#
# Registre:
#
# - arquitetura escolhida;
# - quantidade aproximada de parâmetros;
# - motivo da escolha;
# - camada que será adaptada para as classes do EuroSAT.
#
# **Arquitetura escolhida:**
#
# **Justificativa:**

# %%
# TODO: carregue o modelo pré-treinado e adapte o classificador

# %% [markdown]
# # 4. Funções de treinamento e avaliação
#
# Implemente as funções necessárias para:
#
# - treinamento;
# - validação;
# - cálculo das métricas;
# - armazenamento do histórico;
# - salvamento do melhor checkpoint.
#
# O melhor checkpoint deve ser definido pela **validação**, e não pela última época.

# %%
# TODO: implemente suas funções de treinamento e avaliação

# %% [markdown]
# # 5. Experimento 1 — Feature Extraction
#
# Neste experimento:
#
# - congele o backbone;
# - treine apenas os parâmetros necessários para o novo classificador;
# - registre hiperparâmetros e quantidade de parâmetros treináveis.

# %%
# TODO: configure o modelo para Feature Extraction

# %%
# TODO: execute o treinamento de Feature Extraction

# %% [markdown]
# ## Resultado — Feature Extraction
#
# Registre:
#
# - learning rate;
# - número de épocas;
# - quantidade de parâmetros treináveis;
# - melhor época;
# - melhor acurácia de validação.
#
# **Resultados:**

# %% [markdown]
# # 6. Experimento 2 — Fine-Tuning
#
# Agora permita atualização de parâmetros do backbone.
#
# Utilize **learning rate menor no backbone** e **learning rate maior no classificador**.

# %%
# TODO: configure o modelo e o optimizer para Fine-Tuning

# %%
# TODO: execute o treinamento de Fine-Tuning

# %% [markdown]
# ## Resultado — Fine-Tuning
#
# Registre:
#
# - learning rate do backbone;
# - learning rate do classificador;
# - número de épocas;
# - quantidade de parâmetros treináveis;
# - melhor época;
# - melhor acurácia de validação.
#
# **Resultados:**

# %% [markdown]
# # 7. Comparação dos experimentos
#
# Compare os dois experimentos usando **somente os resultados de validação**.
#
# Apresente:
#
# - curvas de loss;
# - curvas de acurácia;
# - parâmetros treináveis;
# - melhor acurácia de validação;
# - época do melhor resultado;
# - tempo de treinamento.

# %%
# TODO: gere gráficos e tabela comparando Feature Extraction e Fine-Tuning

# %% [markdown]
# ## Análise
#
# Responda:
#
# 1. Qual estratégia apresentou melhor desempenho?
# 2. O ganho de desempenho compensou o custo adicional?
# 3. Houve sinais de overfitting?
# 4. Qual experimento será selecionado para a avaliação final?
#
# **Resposta:**

# %% [markdown]
# # 8. Avaliação final no teste
#
# Escolha o melhor experimento **com base na validação**.
#
# Somente agora utilize o conjunto de teste.
#
# Calcule a acurácia final e mantenha o resultado registrado.

# %%
# TODO: avalie o modelo escolhido no conjunto de teste

# %% [markdown]
# # 9. Matriz de confusão
#
# Gere a matriz de confusão para o resultado final.
#
# Identifique quais pares de classes apresentam mais confusões.

# %%
# TODO: gere e visualize a matriz de confusão

# %% [markdown]
# ## Análise da matriz de confusão
#
# Quais classes foram mais confundidas?
#
# **Resposta:**

# %% [markdown]
# # 10. Análise dos erros
#
# Mostre pelo menos **8 imagens classificadas incorretamente**.
#
# Para cada imagem, apresente:
#
# - classe real;
# - classe prevista.

# %%
# TODO: localize e visualize pelo menos 8 classificações incorretas

# %% [markdown]
# ## Discussão dos erros
#
# Responda:
#
# 1. As classes confundidas possuem características visuais semelhantes?
# 2. Existem erros que parecem compreensíveis ao observar as imagens?
# 3. O que você tentaria modificar para reduzir esses erros?
#
# **Resposta:**

# %% [markdown]
# # 11. Salvamento do modelo
#
# Salve o melhor modelo e seus metadados.
#
# Estrutura esperada:
#
# ```text
# artifacts/
# ├── modelo_eurosat.pt
# └── metadata.json
# ```
#
# O metadata deve registrar pelo menos:
#
# - arquitetura;
# - classes;
# - tamanho de entrada;
# - normalização;
# - estratégia escolhida;
# - melhor acurácia de validação;
# - acurácia final de teste.

# %%
# TODO: salve o melhor modelo e metadata.json

# %% [markdown]
# # 12. Conclusão
#
# Escreva uma conclusão curta respondendo:
#
# 1. Qual arquitetura foi utilizada?
# 2. Feature Extraction ou Fine-Tuning obteve o melhor resultado?
# 3. Qual foi a acurácia final no teste?
# 4. Qual solução você escolheria para produção?
# 5. Qual é a principal limitação do experimento?
#
# **Conclusão:**

# %% [markdown]
# ---
#
# ## Checklist final
#
# - [ ] EuroSAT explorado
# - [ ] Divisão 70/15/15 com seed 42
# - [ ] Backbone diferente de MobileNetV3-Small
# - [ ] Pré-processamento compatível com pesos pré-treinados
# - [ ] Feature Extraction executado
# - [ ] Fine-Tuning executado
# - [ ] Melhor checkpoint salvo
# - [ ] Experimentos comparados pela validação
# - [ ] Teste usado somente na avaliação final
# - [ ] Matriz de confusão
# - [ ] Pelo menos 8 erros analisados
# - [ ] Modelo e metadata salvos
# - [ ] Conclusão preenchida
